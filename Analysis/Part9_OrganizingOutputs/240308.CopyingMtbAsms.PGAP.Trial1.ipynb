# %% [markdown]
# # Organizing annotated genome assemblies (Mtb-151CI) - Trial Run
#
# ### Maximillian Marin (maximillian_marin@hms.harvard.edu)

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import json
# %matplotlib inline

# %% [markdown]
# ### Set matplotlib text export settings for Adobe Illustrator

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %% [markdown]
# #### Pandas Viewing Settings

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
plt.style.use('../nqo.mplstyle')

# %% [markdown]
# ## Define paths to sample metadata files

# %%
# !ls -1 ../../Data
# Out:
# 230905_Ecoli_50CI_Metadata_Shaw2021
# 231121_HybridMtbAsm_QCPass_Meta_Set3_AsmPolishStats_OLD
# 231121.InputAsmTSVs.MtbSetV3.151CI
# 231130_Mtb_HybridVsSR_AsmSummary_TSVs
# 240116.PG_Results
# Ecoli_50CI_Phylo
# Evaluate_SRAsmPGAnalysis_WiHybridAsm
# MtbPangenomeAnalysis_SetV3
# README.md
# SRAENA_RunMetadata

# %%
Repo_DataDir = "../../Data"
InputAsmPath_Dir = f"{Repo_DataDir}/231121.InputAsmTSVs.MtbSetV3.151CI"

MtbSetV3_151CI_InputAsmPATHs_TSV = f"{InputAsmPath_Dir}/231121.MtbSetV3.151CI.HybridAndSRAsm.FAPATHs.V1.tsv"

MtbSetV3_151CI_AsmSumm_TSV = f"{InputAsmPath_Dir}/231121.MtbSetV3.151CI.HybridAsm.AsmSummary.V2.tsv"

# %% [markdown]
# ## PARSE PATHs FOR ALL assemblies processed by this pipeline

# %%
WGA158CI_LRandSR_Asm_Path_DF = pd.read_csv(MtbSetV3_151CI_InputAsmPATHs_TSV, sep = "\t")

WGA158CI_LRandSR_Asm_Path_DF.columns = ['SampleID', 'Dataset_Tag',
                                        'Genome_LR_ASM_PATH', 'Genome_SR_ASM_PATH']

# %%
WGA158CI_LRandSR_Asm_Path_DF.head(1)
# Out:
#   SampleID     Dataset_Tag                                 Genome_LR_ASM_PATH                                 Genome_SR_ASM_PATH
# 0    N0072  ChinerOms_2019  /n/data1/hms/dbmi/farhat/mm774/Projects/231121...  /n/data1/hms/dbmi/farhat/mm774/Projects/231121...

# %%
#WGA158CI_LRandSR_Asm_Path_DF[['SampleID', 'Dataset_Tag', 'Genome_LR_ASM_PATH']]

# %% [markdown]
# ## Parse sample Metadata (N = 151)

# %%
WGA151CI_AsmSummary_DF = pd.read_csv(MtbSetV3_151CI_AsmSumm_TSV, sep = "\t")

SampleIDs_151CI_SOI = list( WGA151CI_AsmSummary_DF["SampleID"].values )
WGA151CI_SampleIDs = SampleIDs_151CI_SOI

#print(','.join(SampleIDs_151CI_SOI) )

ID_To_PrimLineage_Dict = dict(WGA151CI_AsmSummary_DF[['SampleID', 'PrimaryLineage']].values)
ID_To_SubLineage_Dict = dict( WGA151CI_AsmSummary_DF[["SampleID", "Lineage"]].values)
ID_To_Dataset_Dict = dict(WGA151CI_AsmSummary_DF[['SampleID', 'Dataset_Tag']].values)
WGA151CI_AsmSummary_DF.shape
# Out:
# (151, 7)

# %%
WGA151CI_AsmSummary_DF.head(3)
# Out:
#   SampleID  numContigs_Complete  Flye_CircContig_Cov PrimaryLineage                                          Lineage         Dataset_Tag                AsmApproach
# 0    N0072                    1                  358       lineage1                 lineage1,lineage1.1,lineage1.1.2      ChinerOms_2019  PBrs2_LR_Flye_I3_SR_Pilon
# 1    N0153                    1                  372       lineage1  lineage1,lineage1.1,lineage1.1.1,lineage1.1.1.1      ChinerOms_2019  PBrs2_LR_Flye_I3_SR_Pilon
# 2   TB3113                    1                  933       lineage2                 lineage2,lineage2.2,lineage2.2.1  TB_Portals_24CI_R1  PBrs2_LR_Flye_I3_SR_Pilon

# %% [markdown]
# #### What is the lineage breakdown?

# %%
WGA151CI_AsmSummary_DF["PrimaryLineage"].value_counts()
# Out:
# lineage4    62
# lineage2    61
# lineage1    15
# lineage3     7
# lineage6     3
# lineage5     2
# lineage8     1
# Name: PrimaryLineage, dtype: int64

# %% [markdown]
# #### What is the datasets are contributing to our 151 Mtb isolates?

# %%
WGA151CI_AsmSummary_DF["Dataset_Tag"].value_counts()
# Out:
# Hall2022                78
# TB_Portals_24CI_R1      21
# Peker2021               17
# Farhat_Peru_2019        13
# ChinerOms_2019          12
# TRUST_PB_Set1            8
# Lee2020_Elife            1
# Ngabonziza_Lin8_2020     1
# Name: Dataset_Tag, dtype: int64

# %% [markdown]
# #### What is the breakdown of hybrid assembly approaches used?
# - 1 - `PBrs2_LR_Flye_I3_SR_Pilon` (N = 48) <br>
#    PacBio RSII subreads assembled and polished (Flye), then polished w/ short-reads (Pilon)
#
# - 2 - `PBccs_LR_Flye_I3_SR_Pilon` (N = 8) <br>
#    PacBio Sequel II HiFi reads assembled and polished (Flye), then polished w/ short-reads (Pilon)
#
# - 3 - `ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish` (N= 95) <br>
#    Oxford Nanopore (9.4.1) reads assembled and polished (Flye, Medaka), then polished w/ short-reads (Pilon, PolyPolish)

# %%
WGA151CI_AsmSummary_DF["AsmApproach"].value_counts()
# Out:
# ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish    95
# PBrs2_LR_Flye_I3_SR_Pilon                48
# PBccs_LR_Flye_I3_SR_Pilon                 8
# Name: AsmApproach, dtype: int64

# %%
Asm_PBonly_DF = WGA151CI_AsmSummary_DF.query("AsmApproach != 'ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish'  ")
Asm_PBonly_DF.shape
# Out:
# (56, 7)

# %%
Asm_PBonlyOrL1L3_DF = WGA151CI_AsmSummary_DF.query("(AsmApproach != 'ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish') | (PrimaryLineage == 'lineage1') | (PrimaryLineage == 'lineage3')") 

SelectedIDs_69CI = Asm_PBonlyOrL1L3_DF["SampleID"].values

Asm_PBonlyOrL1L3_DF.shape
# Out:
# (73, 7)

# %%
Asm_PBonlyOrL1L3_DF["PrimaryLineage"].value_counts()
# Out:
# lineage4    26
# lineage2    19
# lineage1    15
# lineage3     7
# lineage6     3
# lineage5     2
# lineage8     1
# Name: PrimaryLineage, dtype: int64

# %%
Asm_PBonlyOrL1L3_DF["PrimaryLineage"].value_counts()
# Out:
# lineage4    26
# lineage2    19
# lineage1    15
# lineage3     7
# lineage6     3
# lineage5     2
# lineage8     1
# Name: PrimaryLineage, dtype: int64

# %%
Asm_PBonlyOrL1L3_DF["Dataset_Tag"].value_counts()
# Out:
# TB_Portals_24CI_R1      21
# Hall2022                14
# Farhat_Peru_2019        13
# ChinerOms_2019          12
# TRUST_PB_Set1            8
# Peker2021                3
# Lee2020_Elife            1
# Ngabonziza_Lin8_2020     1
# Name: Dataset_Tag, dtype: int64

# %%
Asm_PBonly_DF["Dataset_Tag"].value_counts()
# Out:
# TB_Portals_24CI_R1      21
# Farhat_Peru_2019        13
# ChinerOms_2019          12
# TRUST_PB_Set1            8
# Lee2020_Elife            1
# Ngabonziza_Lin8_2020     1
# Name: Dataset_Tag, dtype: int64

# %%
WGA151CI_AsmSummary_DF["PrimaryLineage"].value_counts()
# Out:
# lineage4    62
# lineage2    61
# lineage1    15
# lineage3     7
# lineage6     3
# lineage5     2
# lineage8     1
# Name: PrimaryLineage, dtype: int64

# %%
Asm_PBonly_DF["PrimaryLineage"].value_counts()
# Out:
# lineage4    26
# lineage2    19
# lineage3     3
# lineage6     3
# lineage1     2
# lineage5     2
# lineage8     1
# Name: PrimaryLineage, dtype: int64

# %%
Asm_PBonly_DF["Lineage"].value_counts()
# Out:
# lineage2,lineage2.2,lineage2.2.1                   13
# lineage4,lineage4.3,lineage4.3.3                    5
# lineage2.2.1.1                                      4
# lineage4,lineage4.1,lineage4.1.2,lineage4.1.2.1     4
# lineage3                                            3
# lineage6,lineageBOV_AFRI                            3
# lineage4,lineage4.5                                 2
# lineage4.4.1.1                                      2
# lineage4,lineage4.4,lineage4.4.1                    2
# lineage4,lineage4.4,lineage4.4.1,lineage4.4.1.1     2
# lineage4,lineage4.1,lineage4.1.2                    2
# lineage5                                            2
# lineage4,lineage4.8                                 1
# lineage2.2.1                                        1
# lineage8                                            1
# lineage1,lineage1.1,lineage1.1.2                    1
# lineage4,lineage4.2,lineage4.2.1                    1
# lineage4,lineage4.6,lineage4.6.2                    1
# lineage1,lineage1.1,lineage1.1.1,lineage1.1.1.1     1
# lineage4,lineage4.3,lineage4.3.2                    1
# lineage4,lineage4.1,lineage4.1.1                    1
# lineage4                                            1
# lineage2,lineage2.2,lineage2.2.1,lineage2.2.1.1     1
# lineage4.1.1.3                                      1
# Name: Lineage, dtype: int64

# %%
Asm_PBonlyOrL1L3_DF
# Out:
#        SampleID  numContigs_Complete  Flye_CircContig_Cov PrimaryLineage                                          Lineage           Dataset_Tag                            AsmApproach
# 0         N0072                    1                  358       lineage1                 lineage1,lineage1.1,lineage1.1.2        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 1         N0153                    1                  372       lineage1  lineage1,lineage1.1,lineage1.1.1,lineage1.1.1.1        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 2        TB3113                    1                  933       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 3        TB1236                    1                  374       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 4        TB2659                    1                  421       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 5        TB2780                    1                  877       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 6        TB1612                    1                  373       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 7        TB2512                    1                  913       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 8        TB2981                    1                  961       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 9        TB3091                    1                  955       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 10   M0003941_3                    1                  206       lineage2                 lineage2,lineage2.2,lineage2.2.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 11       TB3368                    1                  753       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 12        N0145                    1                  344       lineage2  lineage2,lineage2.2,lineage2.2.1,lineage2.2.1.1        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 13        N0155                    1                  335       lineage2                 lineage2,lineage2.2,lineage2.2.1        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 14       TB2995                    1                  437       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 15       TB3396                    1                  807       lineage2                 lineage2,lineage2.2,lineage2.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 16        N0004                    1                  259       lineage3                                         lineage3        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 17        N1274                    1                  366       lineage3                                         lineage3        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 18        N0054                    1                  225       lineage3                                         lineage3        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 19     02_R1179                    1                  249       lineage4                 lineage4,lineage4.3,lineage4.3.3      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 20     01_R1134                    1                  138       lineage4                                         lineage4      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 21   M0017522_5                    1                  163       lineage4                 lineage4,lineage4.1,lineage4.1.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 22   M0016395_7                    1                  195       lineage4                 lineage4,lineage4.3,lineage4.3.2      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 23   M0010874_7                    1                  172       lineage4                 lineage4,lineage4.3,lineage4.3.3      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 24     02_R1708                    1                  193       lineage4  lineage4,lineage4.1,lineage4.1.2,lineage4.1.2.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 25     02_R0894                    1                  191       lineage4  lineage4,lineage4.1,lineage4.1.2,lineage4.1.2.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 26     01_R1430                    1                  227       lineage4                 lineage4,lineage4.4,lineage4.4.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 27   M0014888_3                    1                  194       lineage4  lineage4,lineage4.1,lineage4.1.2,lineage4.1.2.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 28     02_R1896                    1                  195       lineage4  lineage4,lineage4.4,lineage4.4.1,lineage4.4.1.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 29       TB4620                    1                  964       lineage4                              lineage4,lineage4.5    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 30       TB3162                    1                  859       lineage4                 lineage4,lineage4.3,lineage4.3.3    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 31      MT_0080                    1                  234       lineage4                 lineage4,lineage4.1,lineage4.1.2         Lee2020_Elife              PBrs2_LR_Flye_I3_SR_Pilon
# 32       TB3054                    1                  960       lineage4                 lineage4,lineage4.6,lineage4.6.2    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 33       TB3251                    1                  497       lineage4                 lineage4,lineage4.2,lineage4.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 34   M0016737_0                    1                  162       lineage4                              lineage4,lineage4.5      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 35       TB2661                    1                   86       lineage4                 lineage4,lineage4.3,lineage4.3.3    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 36       TB3237                    1                  559       lineage4  lineage4,lineage4.4,lineage4.4.1,lineage4.4.1.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 37       TB3169                    1                  677       lineage4  lineage4,lineage4.1,lineage4.1.2,lineage4.1.2.1    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 38       TB3386                    1                  555       lineage4                 lineage4,lineage4.3,lineage4.3.3    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 39       TB3334                    1                  689       lineage4                 lineage4,lineage4.1,lineage4.1.2    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 40   M0011368_9                    1                  203       lineage4                 lineage4,lineage4.4,lineage4.4.1      Farhat_Peru_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 41       TB2968                    1                  646       lineage4                              lineage4,lineage4.8    TB_Portals_24CI_R1              PBrs2_LR_Flye_I3_SR_Pilon
# 42        N1272                    1                  370       lineage5                                         lineage5        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 43        N1176                    1                  205       lineage5                                         lineage5        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 44        N1202                    1                  362       lineage6                         lineage6,lineageBOV_AFRI        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 45        N1177                    1                  338       lineage6                         lineage6,lineageBOV_AFRI        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 46        N0091                    1                  345       lineage6                         lineage6,lineageBOV_AFRI        ChinerOms_2019              PBrs2_LR_Flye_I3_SR_Pilon
# 47     RW-TB008                    1                  160       lineage8                                         lineage8  Ngabonziza_Lin8_2020              PBrs2_LR_Flye_I3_SR_Pilon
# 56         QC-3                    1                   70       lineage3                                         lineage3             Peker2021  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 57         QC-9                    1                   37       lineage3                                         lineage3             Peker2021  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 58         QC-5                    1                  111       lineage3                                         lineage3             Peker2021  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 65    mada_1-10                    1                  146       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 66    mada_2-46                    1                  115       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 67     mada_1-1                    1                   94       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 68    mada_1-36                    1                  114       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 69    mada_1-39                    1                  146       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 70    mada_1-51                    1                  149       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 71    mada_1-44                    1                  133       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 72     mada_117                    1                  149       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 73     mada_118                    1                  148       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 74     mada_122                    1                  118       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 75     mada_107                    1                  120       lineage1                                     lineage1.1.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 76       R27252                    1                  149       lineage1                                     lineage1.2.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 77       R23887                    1                  149       lineage1                                     lineage1.2.2              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 112   mada_1-30                    1                  115       lineage3                                     lineage3.1.1              Hall2022  ONT9.4_LR_FlyeI3M_SR_Pilon_PolyPolish
# 143    S0070-08                    1                   69       lineage2                                     lineage2.2.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 144    S0085-01                    1                   39       lineage2                                   lineage2.2.1.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 145    S0107-01                    1                   64       lineage2                                   lineage2.2.1.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 146    S0089-01                    1                   40       lineage2                                   lineage2.2.1.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 147    S0256-08                    1                   53       lineage2                                   lineage2.2.1.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 148    S0123-01                    1                   57       lineage4                                   lineage4.4.1.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 149    S0106-01                    1                   59       lineage4                                   lineage4.1.1.3         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon
# 150    S0262-02                    1                   44       lineage4                                   lineage4.4.1.1         TRUST_PB_Set1              PBccs_LR_Flye_I3_SR_Pilon

# %% [markdown]
# # Define output dir of the Mtb-WGA-SMK processing pipeline

# %%
# Define pipeline output directories

Mtb_WGA_SMK_Outputs_Dir = "/n/data1/hms/dbmi/farhat/mm774/Projects/Mtb-WGA-SMK-Output"

WGA151CI_SMK_OutputDir = Mtb_WGA_SMK_Outputs_Dir + "/231121_MtbSetV3_151CI"

Mtb_SMK_Pipeline_OutputDir = WGA151CI_SMK_OutputDir

# %%
#!ls -alh $Mtb_SMK_Pipeline_OutputDir

# %% [markdown]
# ## Define paths to all BAKTA Annotations (For both Hybrid & SR ASMs)

# %%
listOfSample_Tags = WGA151CI_SampleIDs

target_SMK_OutputDir = Mtb_SMK_Pipeline_OutputDir

SampleTag_ToPaths_Dict = {}

for SampleID in listOfSample_Tags:
    sample_Asm_OutputDir = target_SMK_OutputDir + "/AsmAnalysis/" + SampleID
    GenomeAnno_Dir = f"{sample_Asm_OutputDir}/GenomeAnnotation"
    
    # LR Bakta Anno Files
    Bakta_LR_AsmDir = f"{GenomeAnno_Dir}/{SampleID}_Asm_Bakta"
    
    i_LRAsm_Bakta_GFF = f"{Bakta_LR_AsmDir}/{SampleID}.Bakta.gff3"
    i_LRAsm_Bakta_GBFF = f"{Bakta_LR_AsmDir}/{SampleID}.Bakta.gbff"
    i_LRAsm_Bakta_FAA = f"{Bakta_LR_AsmDir}/{SampleID}.Bakta.faa"
    i_LRAsm_Bakta_FFN = f"{Bakta_LR_AsmDir}/{SampleID}.Bakta.ffn"
    i_LRAsm_Bakta_FNA = f"{Bakta_LR_AsmDir}/{SampleID}.Bakta.fna"
    i_LRAsm_Bakta_TXT = f"{Bakta_LR_AsmDir}/{SampleID}.Bakta.txt"

    # LR PGAP Anno Files
    PGAP_LR_AsmDir = f"{GenomeAnno_Dir}/{SampleID}_Asm_PGAP_V1"
    
    i_LRAsm_PGAP_GFF = f"{PGAP_LR_AsmDir}/{SampleID}.PGAP.gff"
    i_LRAsm_PGAP_FNA = f"{PGAP_LR_AsmDir}/{SampleID}.PGAP.Genome.fasta"
    i_LRAsm_PGAP_WiDNA_GFF = f"{PGAP_LR_AsmDir}/{SampleID}.PGAP.WiDNA.gff"


    
    # SR Bakta Anno Files
    Bakta_SR_AsmDir = f"{GenomeAnno_Dir}/{SampleID}_SR_Asm_Bakta"

    i_SRAsm_Bakta_GFF = f"{Bakta_SR_AsmDir}/{SampleID}.Bakta.gff3"
    i_SRAsm_Bakta_GBFF = f"{Bakta_SR_AsmDir}/{SampleID}.Bakta.gbff"
    i_SRAsm_Bakta_FAA = f"{Bakta_SR_AsmDir}/{SampleID}.Bakta.faa"
    i_SRAsm_Bakta_FFN = f"{Bakta_SR_AsmDir}/{SampleID}.Bakta.ffn"
    i_SRAsm_Bakta_FNA = f"{Bakta_SR_AsmDir}/{SampleID}.Bakta.fna"
    i_SRAsm_Bakta_TXT = f"{Bakta_SR_AsmDir}/{SampleID}.Bakta.txt"

    
    MM2_AsmToRef_Output_Dir = sample_Asm_OutputDir + "/VariantCallingVersusH37Rv/MM2_AsmToH37rv"
    MM2_AsmToH37Rv_BAM = f"{MM2_AsmToRef_Output_Dir}/{SampleID}.mm2.AsmToH37Rv.bam"
    
    dictOfPaths_Temp = {}
    dictOfPaths_Temp["LRAsm_Bakta_GFF"] = i_LRAsm_Bakta_GFF  
    dictOfPaths_Temp["LRAsm_Bakta_GBFF"] = i_LRAsm_Bakta_GBFF
    dictOfPaths_Temp["LRAsm_Bakta_FAA"] = i_LRAsm_Bakta_FAA    
    dictOfPaths_Temp["LRAsm_Bakta_FFN"] = i_LRAsm_Bakta_FFN    
    dictOfPaths_Temp["LRAsm_Bakta_FNA"] = i_LRAsm_Bakta_FNA  
    dictOfPaths_Temp["LRAsm_Bakta_TXT"] = i_LRAsm_Bakta_TXT 

    dictOfPaths_Temp["SRAsm_Bakta_GFF"] = i_SRAsm_Bakta_GFF
    dictOfPaths_Temp["SRAsm_Bakta_GBFF"] = i_SRAsm_Bakta_GBFF
    dictOfPaths_Temp["SRAsm_Bakta_FAA"] = i_SRAsm_Bakta_FAA
    dictOfPaths_Temp["SRAsm_Bakta_FFN"] = i_SRAsm_Bakta_FFN
    dictOfPaths_Temp["SRAsm_Bakta_FNA"] = i_SRAsm_Bakta_FNA
    dictOfPaths_Temp["SRAsm_Bakta_TXT"] = i_SRAsm_Bakta_TXT 

    dictOfPaths_Temp["LRAsm_PGAP_GFF"] = i_LRAsm_PGAP_GFF  
    dictOfPaths_Temp["LRAsm_PGAP_FNA"] = i_LRAsm_PGAP_FNA
    dictOfPaths_Temp["LRAsm_PGAP_WiDNA_GFF"] = i_LRAsm_PGAP_WiDNA_GFF  

    dictOfPaths_Temp["MM2_AsmToH37Rv_BAM"] = MM2_AsmToH37Rv_BAM    
    
    SampleTag_ToPaths_Dict[SampleID] = dictOfPaths_Temp

# %%
# !ls -1 $GenomeAnno_Dir
# Out:
# S0262-02_Asm_Bakta
# S0262-02_Asm_PGAP_V1
# S0262-02_SR_Asm_Bakta
# S0262-02_SR_Asm_PGAP_V1

# %%
# !ls -1 $GenomeAnno_Dir/S0262-02_Asm_PGAP_V1
# Out:
# S0262-02.PGAP.Genome.fasta
# S0262-02.PGAP.gff
# S0262-02.PGAP.gff.InputInfo.tsv
# S0262-02.PGAP.WiDNA.gff

# %%
Proj_Dir = "/n/data1/hms/dbmi/farhat/mm774/Projects"

PGBenchmarking_DataOrg_Dir = f"{Proj_Dir}/240308.PGBenchmarking.DataOrg"
# !mkdir $PGBenchmarking_DataOrg_Dir

Mtb_151CI_AsmDir = f"{PGBenchmarking_DataOrg_Dir}/Mtb.151CI.Hybrid.PGAP.Anno" 
# !mkdir $Mtb_151CI_AsmDir

Mtb_69CI_SelectedSet_AsmDir = f"{PGBenchmarking_DataOrg_Dir}/Mtb.69CI.Hybrid.PGAP.Anno_SelectedForMTBCComp" 
# !mkdir $Mtb_69CI_SelectedSet_AsmDir
# Out:
# mkdir: cannot create directory ‘/n/data1/hms/dbmi/farhat/mm774/Projects/240308.PGBenchmarking.DataOrg’: File exists
# mkdir: cannot create directory ‘/n/data1/hms/dbmi/farhat/mm774/Projects/240308.PGBenchmarking.DataOrg/Mtb.151CI.Hybrid.PGAP.Anno’: File exists
# mkdir: cannot create directory ‘/n/data1/hms/dbmi/farhat/mm774/Projects/240308.PGBenchmarking.DataOrg/Mtb.69CI.Hybrid.PGAP.Anno_SelectedForMTBCComp’: File exists

# %%
# !ls -1 $Mtb_69CI_SelectedSet_AsmDir
# Out:
# 01_R1134.PGAP.Genome.fasta
# 01_R1134.PGAP.gff
# 01_R1430.PGAP.Genome.fasta
# 01_R1430.PGAP.gff
# 02_R0894.PGAP.Genome.fasta
# 02_R0894.PGAP.gff
# 02_R1179.PGAP.Genome.fasta
# 02_R1179.PGAP.gff
# 02_R1708.PGAP.Genome.fasta
# 02_R1708.PGAP.gff
# 02_R1896.PGAP.Genome.fasta
# 02_R1896.PGAP.gff
# M0003941_3.PGAP.Genome.fasta
# M0003941_3.PGAP.gff
# M0010874_7.PGAP.Genome.fasta
# M0010874_7.PGAP.gff
# M0011368_9.PGAP.Genome.fasta
# M0011368_9.PGAP.gff
# M0014888_3.PGAP.Genome.fasta
# M0014888_3.PGAP.gff
# M0016395_7.PGAP.Genome.fasta
# M0016395_7.PGAP.gff
# M0016737_0.PGAP.Genome.fasta
# M0016737_0.PGAP.gff
# M0017522_5.PGAP.Genome.fasta
# M0017522_5.PGAP.gff
# mada_107.PGAP.Genome.fasta
# mada_107.PGAP.gff
# mada_1-10.PGAP.Genome.fasta
# mada_1-10.PGAP.gff
# mada_117.PGAP.Genome.fasta
# mada_117.PGAP.gff
# mada_118.PGAP.Genome.fasta
# mada_118.PGAP.gff
# mada_1-1.PGAP.Genome.fasta
# mada_1-1.PGAP.gff
# mada_122.PGAP.Genome.fasta
# mada_122.PGAP.gff
# mada_1-36.PGAP.Genome.fasta
# mada_1-36.PGAP.gff
# mada_1-39.PGAP.Genome.fasta
# mada_1-39.PGAP.gff
# mada_1-44.PGAP.Genome.fasta
# mada_1-44.PGAP.gff
# mada_1-51.PGAP.Genome.fasta
# mada_1-51.PGAP.gff
# mada_2-46.PGAP.Genome.fasta
# mada_2-46.PGAP.gff
# MT_0080.PGAP.Genome.fasta
# MT_0080.PGAP.gff
# N0004.PGAP.Genome.fasta
# N0004.PGAP.gff
# N0054.PGAP.Genome.fasta
# N0054.PGAP.gff
# N0072.PGAP.Genome.fasta
# N0072.PGAP.gff
# N0072.PGAP.WiDNA.gff
# N0091.PGAP.Genome.fasta
# N0091.PGAP.gff
# N0145.PGAP.Genome.fasta
# N0145.PGAP.gff
# N0153.PGAP.Genome.fasta
# N0153.PGAP.gff
# N0155.PGAP.Genome.fasta
# N0155.PGAP.gff
# N1176.PGAP.Genome.fasta
# N1176.PGAP.gff
# N1177.PGAP.Genome.fasta
# N1177.PGAP.gff
# N1202.PGAP.Genome.fasta
# N1202.PGAP.gff
# N1272.PGAP.Genome.fasta
# N1272.PGAP.gff
# N1274.PGAP.Genome.fasta
# N1274.PGAP.gff
# R23887.PGAP.Genome.fasta
# R23887.PGAP.gff
# R27252.PGAP.Genome.fasta
# R27252.PGAP.gff
# RW-TB008.PGAP.Genome.fasta
# RW-TB008.PGAP.gff
# S0070-08.PGAP.Genome.fasta
# S0070-08.PGAP.gff
# S0085-01.PGAP.Genome.fasta
# S0085-01.PGAP.gff
# S0089-01.PGAP.Genome.fasta
# S0089-01.PGAP.gff
# S0106-01.PGAP.Genome.fasta
# S0106-01.PGAP.gff
# S0107-01.PGAP.Genome.fasta
# S0107-01.PGAP.gff
# S0123-01.PGAP.Genome.fasta
# S0123-01.PGAP.gff
# S0256-08.PGAP.Genome.fasta
# S0256-08.PGAP.gff
# S0262-02.PGAP.Genome.fasta
# S0262-02.PGAP.gff
# TB1236.PGAP.Genome.fasta
# TB1236.PGAP.gff
# TB1612.PGAP.Genome.fasta
# TB1612.PGAP.gff
# TB2512.PGAP.Genome.fasta
# TB2512.PGAP.gff
# TB2659.PGAP.Genome.fasta
# TB2659.PGAP.gff
# TB2661.PGAP.Genome.fasta
# TB2661.PGAP.gff
# TB2780.PGAP.Genome.fasta
# TB2780.PGAP.gff
# TB2968.PGAP.Genome.fasta
# TB2968.PGAP.gff
# TB2981.PGAP.Genome.fasta
# TB2981.PGAP.gff
# TB2995.PGAP.Genome.fasta
# TB2995.PGAP.gff
# TB3054.PGAP.Genome.fasta
# TB3054.PGAP.gff
# TB3091.PGAP.Genome.fasta
# TB3091.PGAP.gff
# TB3113.PGAP.Genome.fasta
# TB3113.PGAP.gff
# TB3162.PGAP.Genome.fasta
# TB3162.PGAP.gff
# TB3169.PGAP.Genome.fasta
# TB3169.PGAP.gff
# TB3237.PGAP.Genome.fasta
# TB3237.PGAP.gff
# TB3251.PGAP.Genome.fasta
# TB3251.PGAP.gff
# TB3334.PGAP.Genome.fasta
# TB3334.PGAP.gff
# TB3368.PGAP.Genome.fasta
# TB3368.PGAP.gff
# TB3386.PGAP.Genome.fasta
# TB3386.PGAP.gff
# TB3396.PGAP.Genome.fasta
# TB3396.PGAP.gff
# TB4620.PGAP.Genome.fasta
# TB4620.PGAP.gff

# %%
len(SelectedIDs_69CI)
# Out:
# 73

# %%
for i_SampleID in SelectedIDs_69CI:
    
    i_Sample_LR_PGAP_GFF_PATH = SampleTag_ToPaths_Dict[i_SampleID]["LRAsm_PGAP_GFF"]
    i_Sample_LR_PGAP_FA_PATH = SampleTag_ToPaths_Dict[i_SampleID]["LRAsm_PGAP_FNA"]

    #print(i_SampleID)

    # !cp $i_Sample_LR_PGAP_GFF_PATH $Mtb_69CI_SelectedSet_AsmDir/
    # !cp $i_Sample_LR_PGAP_FA_PATH $Mtb_69CI_SelectedSet_AsmDir/

    #break

# %%
SampleTag_ToPaths_Dict[i_SampleID]["LRAsm_PGAP_FNA"]
# Out:
# '/n/data1/hms/dbmi/farhat/mm774/Projects/Mtb-WGA-SMK-Output/231121_MtbSetV3_151CI/AsmAnalysis/S0262-02/GenomeAnnotation/S0262-02_Asm_PGAP_V1/S0262-02.PGAP.Genome.fasta'

# %%
#!ls -1 $Mtb_69CI_SelectedSet_AsmDir/

# %%
# !ls -1 /n/data1/hms/dbmi/farhat/mm774/Projects/Mtb-WGA-SMK-Output/231121_MtbSetV3_151CI/AsmAnalysis/N0072/GenomeAnnotation/N0072_Asm_PGAP_V1
# Out:
# N0072.PGAP.Genome.fasta
# N0072.PGAP.gff
# N0072.PGAP.gff.InputInfo.tsv
# N0072.PGAP.WiDNA.gff

# %%
MTBC_PG_MainDir = "/n/data1/hms/dbmi/farhat/mm774/Projects/240308.MTBC_PG_Comparison_ForMarwan"

Asm_PBonlyOrL1L3_DF.to_csv(f"{MTBC_PG_MainDir}/MtbIsolates.AsmInfo.73CI.tsv", sep = "\t")
